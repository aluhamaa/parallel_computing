# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt

# %%
# %%timeit
n_bins = 100
n_test = 10000000

b = n_bins * np.random.normal(size=n_test)**2 + 0.5
hits = np.where(b < (n_bins + 0.5), 1, 0)
# Out:
# 470 ms ± 6.12 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
plt.hist(b, bins=np.arange(0,np.amax(b),np.amax(b)/n_bins), normed=True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.4444613839378">
